# %%
import pandas as pd
import nltk 
from matplotlib import pyplot as plt
import numpy as np 
from matplotlib.pyplot import figure
from _DevNLTKPatentPriorArtFinder import _DevNLTKPatentPriorArtFinder as p

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# Notice that a new "Word2Vec" column has been added

# %%
csv = ('https://raw.githubusercontent.com/GabeAspir/Patent-Prior-Art-Finder/main/Patent%20Queries/resourcesZF/TenWithCitations.csv')
jsonObject1 = pd.io.json.read_json('https://raw.githubusercontent.com/GabeAspir/Patent-Prior-Art-Finder/main/Patent%20Queries/5000PatentsAbstractAndCitationsJson.json')
ppaf = p()
df = ppaf.init(jsonObject1,"Publication_Number", "Abstract")
df
# Out:
#      Publication_Number  ...                                           Word2Vec
# 0      US-2019086938-A1  ...  [-50.77430829480758, 16.21576644665251, -32.62...
# 1      US-2019153590-A1  ...  [-30.9092326241298, 21.791754066944122, -6.217...
# 2      US-2016323114-A1  ...  [-29.992345141443366, 11.146416432166006, -11....
# 3      US-2020010766-A1  ...  [-18.74919435294578, 14.151239333034027, -0.61...
# 4      US-2019373828-A1  ...  [-20.639681453329104, 11.492083525430644, -2.1...
# ...                 ...  ...                                                ...
# 4995   US-2015125446-A1  ...  [-3.795413739979267, 5.739533109590411, 0.5389...
# 4996   US-2016068817-A1  ...  [-19.218764685094357, 16.183804623782635, -0.8...
# 4997   US-2016213693-A1  ...  [-10.65866307169199, 9.188979901373386, -1.735...
# 4998   US-2017042780-A1  ...  [-4.146010205149651, 7.1185372695326805, 1.723...
# 4999   US-2017051302-A1  ...  [-21.241264410316944, 13.194693585857749, 0.01...
#
# ...

# %% [markdown]
# word2vec similarity table

# %%
vecTable = ppaf.word2vecTable(df)
vecTable
# Out:
#                   US-2019086938-A1  ...  US-2017051302-A1
# US-2019086938-A1          1.000000  ...          0.414131
# US-2019153590-A1          0.633435  ...          0.692122
# US-2016323114-A1          0.943772  ...          0.646272
# US-2020010766-A1          0.459666  ...          0.846439
# US-2019373828-A1          0.463549  ...          0.811132
# ...                            ...  ...               ...
# US-2015125446-A1          0.313689  ...          0.774089
# US-2016068817-A1          0.392370  ...          0.979138
# US-2016213693-A1          0.419979  ...          0.911451
# US-2017042780-A1          0.191570  ...          0.715900
# US-2017051302-A1          0.414131  ...          1.000000
#
# [5000 rows x 5000 columns]

# %% [markdown]
# using word2vec to find most similiar to a new patent

# %%
csv2 = ('https://raw.githubusercontent.com/GabeAspir/Patent-Prior-Art-Finder/main/Patent%20Queries/onePatent.csv')
plain_dataframe_patent = pd.read_csv(csv2)
ppaf.compareNewPatentW2V(plain_dataframe_patent, df)
# Out:
#      Publication_Number  Similarity
# 0      US-2018320034-A1    0.125060
# 1      US-2017370948-A1    0.124299
# 2      US-2019270842-A1    0.123372
# 3      US-2017123700-A1    0.123319
# 4          US-5385998-A    0.120078
# ...                 ...         ...
# 4995   US-2017278871-A1   -0.083704
# 4996   US-2019198549-A1   -0.085189
# 4997   US-2018288844-A1   -0.085443
# 4998   US-2018143497-A1   -0.086890
# 4999   US-2017317152-A1   -0.089116
#
# [5000 rows x 2 columns]
